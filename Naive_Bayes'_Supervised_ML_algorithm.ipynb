# %% [markdown]
# <a href="https://colab.research.google.com/github/waghvaishnav/Machine-Learning-Algorithms-and-Data-Processing-Playground-hub/blob/main/Naive_Bayes'_Supervised_ML_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Naive Bayes Algorithm

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
iris = load_iris()

x,y = load_iris(return_X_y=True)

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=42)

GNB = GaussianNB()
GNB.fit(x_train,y_train)

y_prediction = GNB.predict(x_test)

print("gnb or the Accuracy score is :",GNB.score(x_test,y_test))

cm = confusion_matrix(y_test,y_prediction)
print("the confusion matrix : \n")
print(cm)

import seaborn as sns
sns.heatmap(cm,annot=True)
# Out:
# gnb or the Accuracy score is : 0.9866666666666667
# the confusion matrix :
#
# [[29  0  0]
#  [ 0 23  0]
#  [ 0  1 22]]
# <Axes: >
