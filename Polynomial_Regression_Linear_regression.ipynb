# %% [markdown]
# <a href="https://colab.research.google.com/github/waghvaishnav/Machine-Learning-Algorithms-and-Data-Processing-Playground-hub/blob/main/Polynomial_Regression_Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ba425089-4cd4-42ca-80e0-b6298775d9c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba425089-4cd4-42ca-80e0-b6298775d9c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("polynomial_reg.csv")
df.head()
# Out:
#    mileage  selling_price
# 0   126958         343014
# 1   151867         349599
# 2   136932         386067
# 3   108694         293678
# 4   124879         305833

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(x,y,color="orange", label="Original Data")
plt.xlabel("features")
plt.ylabel("target")
plt.legend()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

linear_model = LinearRegression()

poly_reg = PolynomialFeatures(degree=3)           #import polynomial regression.

x = df[["mileage"]]
y = df["selling_price"]

x = std.fit_transform(x)

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

X_train = poly_reg.fit_transform(x_train)
X_test  = poly_reg.transform(x_test)  #only transforms to avoid data leakage .

linear_model.fit(X_train,y_train)
y_pred = linear_model.predict(X_test)

print("mean squared error is ",mean_squared_error(y_test,y_pred))
print("r2 score is ",r2_score(y_test,y_pred))
# Out:
# mean squared error is  1916399859.1162848
# r2 score is  0.5008376476487826
